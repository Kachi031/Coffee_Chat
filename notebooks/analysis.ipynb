# %% [markdown]
# # Analysis
#
# Create your own EDA below! Create as many code-blocks as you need.
#
# Once you've completed your EDA, complete the section titled **Reflections** where you will answer questions about your EDA.

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import coffee data
coffee = pd.read_csv("../data/crop/coffee_output.csv")

# import weather data
weather123 = pd.read_csv("../data/weather/weather_data.csv")

# %%
# TODO: Merge these two dataframes together

Coffee_weather = pd.merge (weather123,coffee,on=["subdivision","year"])
Coffee_weather.to_csv("../data/weather/Coffee_weather.csv", index=False)

# %%
# TODO: View the first 5 rows of your data

Coffee_weather.head()
# Out:
#    year  rain_max   temp_avg   temp_max   temp_min    hum_max    hum_min  \
# 0  2006  6.670968  21.803087  27.190323  18.654839  97.129032  57.806452
# 1  2007  1.866250  23.040999  27.649375  18.753125  87.837500  48.493750
# 2  2008  3.777049  20.682400  27.000000  16.216393  96.136612  51.415301
# 3  2009  3.380220  21.023802  27.769231  16.410440  96.054945  49.329670
# 4  2010  2.183516  21.444293  28.580769  16.156044  95.247253  44.648352
#
#    wind_max  wind_avg   subdivision country     type  60kgs_bag  \
# 0  9.706452  2.075207  Minas Gerais  Brazil  Arabica      16.30
# 1  8.749375  2.069605  Minas Gerais  Brazil  Arabica      23.70
# 2  8.865027  1.584408  Minas Gerais  Brazil  Arabica      16.85
# 3  9.114286  1.611746  Minas Gerais  Brazil  Arabica      25.55
# 4  9.109341  1.455907  Minas Gerais  Brazil  Arabica      22.10
#
#    nonbearing_trees  bearing_trees  nonbear_hectares  bearing_hectares  \
# ...

# %%
# TODO: Check for null values 

Coffee_weather.dropna()
# Out:
#     year  rain_max   temp_avg   temp_max   temp_min    hum_max    hum_min  \
# 0   2006  6.670968  21.803087  27.190323  18.654839  97.129032  57.806452
# 1   2007  1.866250  23.040999  27.649375  18.753125  87.837500  48.493750
# 2   2008  3.777049  20.682400  27.000000  16.216393  96.136612  51.415301
# 3   2009  3.380220  21.023802  27.769231  16.410440  96.054945  49.329670
# 4   2010  2.183516  21.444293  28.580769  16.156044  95.247253  44.648352
# 5   2011  2.601786  20.959536  27.735714  16.318132  96.060440  49.252747
# 6   2012  2.255738  21.030624  28.406011  16.003279  96.060109  46.366120
# 7   2013  3.079121  21.088660  27.976923  16.386813  96.802198  49.390110
# 8   2014  1.617582  21.163462  28.406044  15.684066  96.214286  44.824176
# 9   2015  2.876923  21.346828  28.487912  16.475275  97.450549  48.406593
# 10  2016  2.641860  21.630402  28.855233  16.705233  97.587209  47.587209
# 11  2017  2.052459  21.404627  28.433607  16.409016  97.155738  47.475410
# ...

# %%
# TODO: Drop rows that contain null values

Coffee_weather.notnull()
# Out:
#     year  rain_max  temp_avg  temp_max  temp_min  hum_max  hum_min  wind_max  \
# 0   True      True      True      True      True     True     True      True
# 1   True      True      True      True      True     True     True      True
# 2   True      True      True      True      True     True     True      True
# 3   True      True      True      True      True     True     True      True
# 4   True      True      True      True      True     True     True      True
# 5   True      True      True      True      True     True     True      True
# 6   True      True      True      True      True     True     True      True
# 7   True      True      True      True      True     True     True      True
# 8   True      True      True      True      True     True     True      True
# 9   True      True      True      True      True     True     True      True
# 10  True      True      True      True      True     True     True      True
# ...

# %%
# TODO: BEGIN YOUR EDA!

Coffee_weather[["temp_avg","60kgs_bag"]].corr()
# Out:
#            temp_avg  60kgs_bag
# temp_avg   1.000000  -0.122697
# 60kgs_bag -0.122697   1.000000

# %%
Coffee_weather[["hum_min","60kgs_bag"]].corr()
# Out:
#             hum_min  60kgs_bag
# hum_min    1.000000  -0.544749
# 60kgs_bag -0.544749   1.000000

# %%
Coffee_weather[["rain_max","60kgs_bag"]].corr()
# Out:
#            rain_max  60kgs_bag
# rain_max   1.000000  -0.385792
# 60kgs_bag -0.385792   1.000000

# %%
Coffee_weather[["wind_avg","60kgs_bag"]].corr()
# Out:
#            wind_avg  60kgs_bag
# wind_avg   1.000000  -0.704927
# 60kgs_bag -0.704927   1.000000

# %%
sns.scatterplot(x=Coffee_weather["wind_avg"], y=Coffee_weather["bearing_trees"])
# Out:
# <Axes: xlabel='wind_avg', ylabel='bearing_trees'>

# %%
sns.scatterplot(x=Coffee_weather["temp_avg"], y=Coffee_weather["nonbearing_trees"])
# Out:
# <Axes: xlabel='temp_avg', ylabel='nonbearing_trees'>

# %%
sns.scatterplot(x=Coffee_weather["rain_max"], y=Coffee_weather["bearing_trees_per_hectare"])
# Out:
# <Axes: xlabel='rain_max', ylabel='bearing_trees_per_hectare'>

# %%
sns.scatterplot(x=Coffee_weather["hum_min"], y=Coffee_weather["bearing_trees"])
# Out:
# <Axes: xlabel='hum_min', ylabel='bearing_trees'>

# %% [markdown]
# ## Reflections
#
# Answer each question based on the visualizations that you've generated.
#
# Remember, you must justify your answers with proof! Look back to W6D3 for more context.

# %% [markdown]
# What is the relationship between temp_avg and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# Based on the pearson's correlation coefficient, Temp_avg and 60kgs bag have a negative relationship, with values of 1.000000 and -0.122697. The data frame showcases that within the last two years, 2022 and 2023, 60kg_bags has increased from 24.50 to 28.50 and temp avg has increase from 20.704556 to 21.046566.

# %% [markdown]
# What is the relationship between minimum humidity and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# Based on the pearson's correlation coefficient, minimum humidity and 60kgs bag have a negative relationship, with values of 1.000000 and -0.544749. Within the last two years, there has been an increase from year 2021 to 2023, 44.824176 to 48.857143 for hum_min and 60kg_bag has decreased from 34.80 to 24.50 from 2021 to 2022 but has increased back up to 28.50 in 2023.

# %% [markdown]
# What is the relationship between rain_max and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# Based on the pearson's correlation coefficient, rain_max and 60kgs bag have a negative relationship, with values of 1.000000 and -0.385792.

# %% [markdown]
# What is the relationship between average wind speed and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# Based on the pearson's correlation coefficient, average wind speed and 60kgs bag have a negative relationship with values of 1.000000 and -0.704927.

# %% [markdown]
# Perform the same bivariate analysis between the mentioned weather columns (temp_avg, hum_min, rain_max, and wind_avg) and a coffee-related column of your choice (bearing_trees, nonbearing_trees, bearing_trees_per_hectare, etc). Which directions do these relationships follow? What are the strengths of these relationships?
#
# Based on the scatter plot created, the less the temperature average, the higher the nonbearing trees are. As the temp decreases from 20.831525 to 20.704556 (2021-2022), nonbearing trees increases within the same year from 1050 to 1500 according to the data frame.
#
# It appears as though minimum humidity and bearing trees have a strong relationship. As hum_min increased from 44.824176 to 48.857143 in 2021 to 2023, bearing trees has decreased during the same time period from 6200 to 6010 but has increased back up to 6100.
#
# According to the scatter plot created for rain max and bearing trees hectares, the direction shows a steadily increase in both areas as the years pass.

# %% [markdown]
# Which weather factor seems to influence coffee production the most?
#
# The factor that influences coffee production the most is temperature. Any fluctuation in temperature can affect coffee plant growth. Whether the weather is too warm or too cold, it can negatively impact the growth of the coffee plants.

# %% [markdown]
# Which data would you collect to continue exploring the impacts of weather and economic forces on coffee production?
#
# If I was to continue exploring the impacts of weather and economic force on coffee production, I would focus on global warming. With the current status of an increase of Global temperature, it can have a impact to the coffee production. Global warming can impact the patterns of the rainfall and can lead to an increase in heat which will have a negative impact on the coffee plant growth.

# %% [markdown]
# If you were preparing a report to provide coffee farmers, which weather condititions would you state are the most favorable for coffee growing (assuming any exist)?
#
# The weather conditions that is most favorable for coffee growing is a warm tropical climate with moderate rain and a sufficient humiity state. The rainfall will be very beneficial in allowing the coffee plants to stay hydrated, thus making it more robust. The humidity places an important role in preserving the soil moisture from harmful heat waves.  There has to be a solid environment with not much temperature fluctuation.
